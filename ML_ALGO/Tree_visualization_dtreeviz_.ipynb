# %%
# !pip install dtreeviz
# Out:
# Collecting dtreeviz
#   Obtaining dependency information for dtreeviz from https://files.pythonhosted.org/packages/b3/e8/44eb59345d8ba9d2f6610df6441d63082f46021c1685de24716c22f55383/dtreeviz-2.2.2-py3-none-any.whl.metadata
#   Downloading dtreeviz-2.2.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting graphviz>=0.9 (from dtreeviz)
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from dtreeviz) (2.1.4)
# Requirement already satisfied: numpy in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from dtreeviz) (1.24.3)
# Requirement already satisfied: scikit-learn in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from dtreeviz) (1.3.0)
# Requirement already satisfied: matplotlib in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from dtreeviz) (3.7.1)
# Collecting colour (from dtreeviz)
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pytest in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from dtreeviz) (7.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from matplotlib->dtreeviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from pandas->dtreeviz) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from pandas->dtreeviz) (2023.4)
# Requirement already satisfied: iniconfig in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from pytest->dtreeviz) (1.0.0)
# Requirement already satisfied: scipy>=1.5.0 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/vishalpatel/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)
# Downloading dtreeviz-2.2.2-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: colour, graphviz, dtreeviz
# Successfully installed colour-0.1.5 dtreeviz-2.2.2 graphviz-0.20.1

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# # 1. Classification

# %%
# from dtreeviz.trees import dtreeviz
# Assuming you have already imported necessary libraries and trained a decision tree model

# Import the necessary module
from dtreeviz import dtreeviz

# Assuming 'clas' is your decision tree model
viz = dtreeviz(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])
viz

viz = dtreeviz(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])
viz
# Out:
# /var/folders/kt/_wys5q9j4f5cxnwphmf7mxjh0000gn/T/ipykernel_17993/4144051516.py:8: DeprecationWarning: dtreeviz() function is deprecated starting from version 2.0.
#  For the same functionality, please use this code instead:
#  m = dtreeviz.model(...)
#  m.view()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       5 from dtreeviz import dtreeviz
#       7 # Assuming 'clas' is your decision tree model
# ----> 8 viz = dtreeviz(clas,
#       9                X_train,
#      10                y_train,
#      11                feature_names=iris.feature_names,
#      12                class_names=["setosa", "versicolor", "virginica"])
#      13 viz
#      15 viz = dtreeviz(clas,
#      16                X_train,
#      17                y_train,
#      18                feature_names=iris.feature_names,
#      19                class_names=["setosa", "versicolor", "virginica"])
#
# File ~/anaconda3/lib/python3.11/site-packages/dtreeviz/compatibility.py:254, in dtreeviz(tree_model, X_train, y_train, feature_names, target_name, class_names, tree_index, precision, orientation, instance_orientation, show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, highlight_path, X, max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize, fontname, title, title_fontsize, colors, scale)
#     251 shadow_tree = ShadowDecTree.get_shadow_tree(tree_model, X_train, y_train, feature_names, target_name, class_names,
#     252                                             tree_index)
#     253 model = DTreeVizAPI(shadow_tree)
# --> 254 return model.view(precision, orientation,
#     255                   instance_orientation,
#     256                   show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, highlight_path, X,
#     257                   max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize,
#     258                   fontname, title, title_fontsize, colors=colors, scale=scale)
#
# File ~/anaconda3/lib/python3.11/site-packages/dtreeviz/trees.py:523, in DTreeVizAPI.view(self, precision, orientation, instance_orientation, show_root_edge_labels, show_node_labels, show_just_path, fancy, histtype, leaftype, highlight_path, x, max_X_features_LR, max_X_features_TD, depth_range_to_display, label_fontsize, ticks_fontsize, fontname, title, title_fontsize, colors, scale)
#     521 tmp = tempfile.gettempdir()
#     522 if x is not None:
# --> 523     path = self.shadow_tree.predict_path(x)
#     524     highlight_path = [n.id for n in path]
#     526 color_values = colors['classes'][n_classes]
#
# File ~/anaconda3/lib/python3.11/site-packages/dtreeviz/models/shadow_decision_tree.py:340, in ShadowDecTree.predict_path(self, x)
#     337     return walk(t.right, x, path)
#     339 path = []
# --> 340 walk(self.root, x, path)
#     341 return path
#
# File ~/anaconda3/lib/python3.11/site-packages/dtreeviz/models/shadow_decision_tree.py:335, in ShadowDecTree.predict_path.<locals>.walk(t, x, path)
#     333 if t.isleaf():
#     334     return None
# --> 335 if self.shouldGoLeftAtSplit(t.id, x[t.feature()]):
#     336     return walk(t.left, x, path)
#     337 return walk(t.right, x, path)
#
# TypeError: 'int' object is not subscriptable
