# %% [markdown]
# # Machine Learning Finding Optimal Model and Hyperparameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn import datasets
digits = datasets.load_digits()

# %%
X = digits.data
y = digits.target

# %%
X.shape
# Out:
# (1797, 64)

# %%
y.shape
# Out:
# (1797,)

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Define the hyper paramters.

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    },
    'naive_bayes_gaussian': {
        'model': GaussianNB(),
        'params': {}
    },
    'naive_bayes_multinomial': {
        'model': MultinomialNB(),
        'params': {}
    },
    'decision_tree': {
        'model': DecisionTreeClassifier(),
        'params': {
            'criterion': ['gini','entropy'],
            
        }
    }     
}

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
import pandas as pd
scores = []

# %%
import time

# Start the timer
start_time = time.time()


for mn,mp in model_params.items():
    clf = GridSearchCV(mp["model"],mp['params'],cv=5, return_train_score=False)
    clf.fit(X,y)
    scores.append({
        "model":mn,
        "best_score":clf.best_score_,
        "best_params":clf.best_params_,
        "best_estimators":clf.best_estimator_
    })


# End the timer
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time
print("Time taken:", elapsed_time, "seconds")
# Out:
# Time taken: 5.065934896469116 seconds

# %%
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                       model  best_score                   best_params
# 0                       svm    0.947697  {'C': 1, 'kernel': 'linear'}
# 1             random_forest    0.899873          {'n_estimators': 10}
# 2       logistic_regression    0.922114                      {'C': 1}
# 3      naive_bayes_gaussian    0.806928                            {}
# 4   naive_bayes_multinomial    0.870350                            {}
# 5             decision_tree    0.803589      {'criterion': 'entropy'}
# 6                       svm    0.947697  {'C': 1, 'kernel': 'linear'}
# 7             random_forest    0.898200          {'n_estimators': 10}
# 8       logistic_regression    0.922114                      {'C': 1}
# 9      naive_bayes_gaussian    0.806928                            {}
# 10  naive_bayes_multinomial    0.870350                            {}
# 11            decision_tree    0.803595      {'criterion': 'entropy'}
# 12                      svm    0.947697  {'C': 1, 'kernel': 'linear'}
# 13            random_forest    0.902640          {'n_estimators': 10}
# 14      logistic_regression    0.922114                      {'C': 1}
# 15     naive_bayes_gaussian    0.806928                            {}
# 16  naive_bayes_multinomial    0.870350                            {}
# 17            decision_tree    0.812493      {'criterion': 'entropy'}

# %%
import time

# Start the timer
start_time = time.time()


for mn,mp in model_params.items():
    clf = RandomizedSearchCV(mp["model"],mp['params'],cv=5, return_train_score=False)
    clf.fit(X,y)
    scores.append({
        "model":mn,
        "best_score":clf.best_score_,
        "best_params":clf.best_params_,
        "best_estimators":clf.best_estimator_
    })

# End the timer
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time
print("Time taken:", elapsed_time, "seconds")
# Out:
# /Users/vishalpatel/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /Users/vishalpatel/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /Users/vishalpatel/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /Users/vishalpatel/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /Users/vishalpatel/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /Users/vishalpatel/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Time taken: 5.1617231369018555 seconds

# %%
df2 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df2
# Out:
#                       model  best_score                   best_params
# 0                       svm    0.947697  {'C': 1, 'kernel': 'linear'}
# 1             random_forest    0.899873          {'n_estimators': 10}
# 2       logistic_regression    0.922114                      {'C': 1}
# 3      naive_bayes_gaussian    0.806928                            {}
# 4   naive_bayes_multinomial    0.870350                            {}
# 5             decision_tree    0.803589      {'criterion': 'entropy'}
# 6                       svm    0.947697  {'C': 1, 'kernel': 'linear'}
# 7             random_forest    0.898200          {'n_estimators': 10}
# 8       logistic_regression    0.922114                      {'C': 1}
# 9      naive_bayes_gaussian    0.806928                            {}
# 10  naive_bayes_multinomial    0.870350                            {}
# 11            decision_tree    0.803595      {'criterion': 'entropy'}
# 12                      svm    0.947697  {'C': 1, 'kernel': 'linear'}
# 13            random_forest    0.902640          {'n_estimators': 10}
# 14      logistic_regression    0.922114                      {'C': 1}
# 15     naive_bayes_gaussian    0.806928                            {}
# 16  naive_bayes_multinomial    0.870350                            {}
# 17            decision_tree    0.812493      {'criterion': 'entropy'}
# 18                      svm    0.947697  {'kernel': 'linear', 'C': 1}
# 19            random_forest    0.897089          {'n_estimators': 10}
# 20      logistic_regression    0.922114                      {'C': 1}
# 21     naive_bayes_gaussian    0.806928                            {}
# 22  naive_bayes_multinomial    0.870350                            {}
# 23            decision_tree    0.811939      {'criterion': 'entropy'}
